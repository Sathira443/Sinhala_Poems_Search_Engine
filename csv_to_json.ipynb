# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
csv_file = '/content/drive/MyDrive/Semester 07/DM & IR/ElasticSearch/DM & IR Mini Project - Sheet.csv'

# %%
import pandas as pd

# Read a CSV file from Google Drive
df = pd.read_csv(csv_file)

# %%
import csv
import json

json_file = '/content/drive/MyDrive/Semester 07/DM & IR/ElasticSearch/metaphoem_data_file.json'  # Replace 'output.json' with your desired JSON file name

data = []

with open(csv_file, 'r', encoding='utf-8') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        data.append(row)

# Prepare the header
header = {"index": {"_index": "metaphoem"}}
output_data = []

# Insert the header before each JSON object
for item in data:
    output_data.append(header)
    output_data.append(item)

# with open(json_file, 'w', encoding='utf-8') as json_file:
#     json.dump(output_data, json_file, ensure_ascii=False)

with open(json_file, 'w', encoding='utf-8') as json_file:
    for item in data:
        # Write the header and item as separate JSON objects in a single line
        json_file.write(json.dumps(header, ensure_ascii=False) + '\n')
        json_file.write(json.dumps(item, ensure_ascii=False) + '\n')

print(f'CSV data has been converted to JSON with headers and saved as {json_file}')
# Out:
# CSV data has been converted to JSON with headers and saved as <_io.TextIOWrapper name='/content/drive/MyDrive/Semester 07/DM & IR/ElasticSearch/metaphoem_data_file.json' mode='w' encoding='utf-8'>
